# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
def sigmoid(x):
    return 1 / (1 + math.exp(-x))
sigmoid(5)
# Out:
# 0.9933071490757153

# %%
plt.plot([2,3,5,2])
plt.show()

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('fast')
x=np.linspace(-10,10,100)
z=1/(1 + np.exp(-x))
plt.plot(x,z)
plt.show()

# %%
fb= pd.read_csv('D:/Data/fb_stock_prices_2018.csv')

# %%
changes=fb.high - fb.low
date=fb.date

# %%
plt.plot(date,changes)
plt.show()

# %%
x = fb.assign(week = pd.DatetimeIndex(fb.date).week)

# %%
dif = x.groupby(['week']).agg({"high":max, "low": min})

dif
# Out:
#           high       low
# week
# 1     186.9000  129.9500
# 2     188.9000  177.4000
# 3     182.3700  175.8000
# 4     190.6600  180.4100
# 5     195.3200  181.8400
# 6     190.6100  167.1800
# 7     180.5000  171.8400
# 8     183.3900  175.1100
# 9     185.6600  172.9900
# 10    185.5100  175.8900
# 11    186.1000  181.1100
# 12    177.1700  159.0200
# 13    162.8500  149.0200
# 14    161.5750  150.5100
# 15    168.6500  156.0400
# 16    169.0000  163.3900
# 17    177.1000  156.1900
# 18    178.0800  170.2300
# 19    188.3200  177.1100
# 20    187.8600  182.2200
# 21    186.9100  182.1800
# 22    194.5492  183.7100
# 23    195.0000  186.4300
# 24    197.2800  188.8000
# 25    203.5500  193.7900
# 26    200.7500  193.1100
# 27    203.6400  192.2200
# 28    208.4300  201.7500
# 29    211.5000  204.8400
# 30    218.6200  173.0000
# 31    178.8500  166.5600
# 32    188.3000  178.3800
# 33    182.6100  172.0400
# 34    175.5500  170.9100
# 35    179.7901  174.7500
# ...

# %%
fb_dif=dif.high-dif.low

# %%
plt.plot(fb_dif)
plt.show()

# %%
v1=fb.high-fb.low
v2=fb.volume

# %%
plt.scatter(v2,v1)

# %%
data = pd.read_csv("D:/Data/earthquakes.csv")

# %%
data1=data.place.str.contains("Indonesia")
df1=data[data1]
magType=df1.magType
df1.boxplot(column='mag', by = 'magType', figsize=(15,10))
